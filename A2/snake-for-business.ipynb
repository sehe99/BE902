# %%
import pygame
import gamedisplay
import board
import snakeai
import time
import direction

# game_speed difficulty settings
# Easy       ->  10
# Medium     ->  25
# Hard       ->  50
# Super hard ->  120
GAME_SPEED = 10
# Change here to switch between A.I and human
USE_AI = True

# This determins the resolution of the game
# Pixels per game tile 
RESOLUTION_MULTIPLIER = 10

# This creates a new board,
# the board handles the logic of the game
# but does not handle any of the graphics
game_board = board.Board(
    board_size_x= 72,
    board_size_y=48  
)

# this creates a new game display,
# this handles anything that is graphical
display = gamedisplay.GameDisplay(game_board, 
    game_resolution_x=game_board.board_size_x*RESOLUTION_MULTIPLIER,
    game_resolution_y=game_board.board_size_y*RESOLUTION_MULTIPLIER
)

# PyGame the framework that does most of the heavy lifting for us
pygame.init()
# Initiates the A.I
ai = snakeai.SnakeAI()

# FPS (frames per second) controller
game_speed_control = pygame.time.Clock()
#Check for the latest key pressed and return the corresponding direction
def get_human_next_move():
    for event in pygame.event.get():
        # Whenever a key is pressed down
        if event.type == pygame.KEYDOWN:
            # W -> Up; S -> Down; A -> Left; D -> Right
            if event.key == pygame.K_UP or event.key == ord('w'):
                return direction.UP
            if event.key == pygame.K_DOWN or event.key == ord('s'):
                return direction.DOWN
            if event.key == pygame.K_LEFT or event.key == ord('a'):
                return direction.LEFT
            if event.key == pygame.K_RIGHT or event.key == ord('d'):
                return direction.RIGHT
# Main logic
while not game_board.is_game_over():
    if USE_AI: 
        next_move = ai.get_next_move(game_board)
    else:
        next_move = get_human_next_move()
    # Tell the game the next desired direction from the player
    game_board.handle_direction_input(next_move)
    # Move the game logic another step
    game_board.tick()
    # update the visible part of the game
    display.draw()
    # make sure the game pauses for a long enough time between each step
    game_speed_control.tick(GAME_SPEED)

# Game is over, draw the final message
display.draw_game_over()
# Sleep for 4 seconds before exiting the game
time.sleep(4)
# Make sure everything shuts down in an orderily fashion
pygame.display.quit()
pygame.quit()
time.sleep(1)
exit()
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Current position:  (15, 10) Board size:  (72, 48)
# 15
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  15 Apple y posiiton:  10
# Current Direction RIGHT
# Current Body Positions:  [(10, 10), (11, 10), (12, 10), (13, 10), (14, 10)]
# AI Decides that snake should go  DOWN
# Options  [(1, 0), (0, 1)]
# Current position:  (15, 10) Board size:  (72, 48)
# 15
# Current position:  (15, 11) Board size:  (72, 48)
# 15
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  15 Apple y posiiton:  11
# Current Direction DOWN
# Current Body Positions:  [(11, 10), (12, 10), (13, 10), (14, 10), (15, 10)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0), (0, 1)]
# Current position:  (15, 11) Board size:  (72, 48)
# 15
# Current position:  (16, 11) Board size:  (72, 48)
# 16
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  16 Apple y posiiton:  11
# Current Direction RIGHT
# Current Body Positions:  [(12, 10), (13, 10), (14, 10), (15, 10), (15, 11)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0), (0, 1)]
# Current position:  (16, 11) Board size:  (72, 48)
# 16
# Current position:  (17, 11) Board size:  (72, 48)
# 17
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  17 Apple y posiiton:  11
# Current Direction RIGHT
# Current Body Positions:  [(13, 10), (14, 10), (15, 10), (15, 11), (16, 11)]
# AI Decides that snake should go  DOWN
# Options  [(1, 0), (0, 1)]
# Current position:  (17, 11) Board size:  (72, 48)
# 17
# Current position:  (17, 12) Board size:  (72, 48)
# 17
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  17 Apple y posiiton:  12
# Current Direction DOWN
# Current Body Positions:  [(14, 10), (15, 10), (15, 11), (16, 11), (17, 11)]
# AI Decides that snake should go  DOWN
# Options  [(1, 0), (0, 1)]
# Current position:  (17, 12) Board size:  (72, 48)
# 17
# Current position:  (17, 13) Board size:  (72, 48)
# 17
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  17 Apple y posiiton:  13
# Current Direction DOWN
# Current Body Positions:  [(15, 10), (15, 11), (16, 11), (17, 11), (17, 12)]
# AI Decides that snake should go  DOWN
# Options  [(1, 0), (0, 1)]
# Current position:  (17, 13) Board size:  (72, 48)
# 17
# Current position:  (17, 14) Board size:  (72, 48)
# 17
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  17 Apple y posiiton:  14
# Current Direction DOWN
# Current Body Positions:  [(15, 11), (16, 11), (17, 11), (17, 12), (17, 13)]
# AI Decides that snake should go  DOWN
# Options  [(1, 0), (0, 1)]
# Current position:  (17, 14) Board size:  (72, 48)
# 17
# Current position:  (17, 15) Board size:  (72, 48)
# 17
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  17 Apple y posiiton:  15
# Current Direction DOWN
# Current Body Positions:  [(16, 11), (17, 11), (17, 12), (17, 13), (17, 14)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0), (0, 1)]
# Current position:  (17, 15) Board size:  (72, 48)
# 17
# Current position:  (18, 15) Board size:  (72, 48)
# 18
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  18 Apple y posiiton:  15
# Current Direction RIGHT
# Current Body Positions:  [(17, 11), (17, 12), (17, 13), (17, 14), (17, 15)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0), (0, 1)]
# Current position:  (18, 15) Board size:  (72, 48)
# 18
# Current position:  (19, 15) Board size:  (72, 48)
# 19
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  19 Apple y posiiton:  15
# Current Direction RIGHT
# Current Body Positions:  [(17, 12), (17, 13), (17, 14), (17, 15), (18, 15)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0), (0, 1)]
# Current position:  (19, 15) Board size:  (72, 48)
# 19
# Current position:  (20, 15) Board size:  (72, 48)
# 20
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  20 Apple y posiiton:  15
# Current Direction RIGHT
# Current Body Positions:  [(17, 13), (17, 14), (17, 15), (18, 15), (19, 15)]
# AI Decides that snake should go  DOWN
# Options  [(1, 0), (0, 1)]
# Current position:  (20, 15) Board size:  (72, 48)
# 20
# Current position:  (20, 16) Board size:  (72, 48)
# 20
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  20 Apple y posiiton:  16
# Current Direction DOWN
# Current Body Positions:  [(17, 14), (17, 15), (18, 15), (19, 15), (20, 15)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (20, 16) Board size:  (72, 48)
# 20
# Current position:  (21, 16) Board size:  (72, 48)
# 21
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  21 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(17, 15), (18, 15), (19, 15), (20, 15), (20, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (21, 16) Board size:  (72, 48)
# 21
# Current position:  (22, 16) Board size:  (72, 48)
# 22
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  22 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(18, 15), (19, 15), (20, 15), (20, 16), (21, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (22, 16) Board size:  (72, 48)
# 22
# Current position:  (23, 16) Board size:  (72, 48)
# 23
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  23 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(19, 15), (20, 15), (20, 16), (21, 16), (22, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (23, 16) Board size:  (72, 48)
# 23
# Current position:  (24, 16) Board size:  (72, 48)
# 24
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  24 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(20, 15), (20, 16), (21, 16), (22, 16), (23, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (24, 16) Board size:  (72, 48)
# 24
# Current position:  (25, 16) Board size:  (72, 48)
# 25
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  25 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(20, 16), (21, 16), (22, 16), (23, 16), (24, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (25, 16) Board size:  (72, 48)
# 25
# Current position:  (26, 16) Board size:  (72, 48)
# 26
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  26 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(21, 16), (22, 16), (23, 16), (24, 16), (25, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (26, 16) Board size:  (72, 48)
# 26
# Current position:  (27, 16) Board size:  (72, 48)
# 27
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  27 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(22, 16), (23, 16), (24, 16), (25, 16), (26, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (27, 16) Board size:  (72, 48)
# 27
# Current position:  (28, 16) Board size:  (72, 48)
# 28
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  28 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(23, 16), (24, 16), (25, 16), (26, 16), (27, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (28, 16) Board size:  (72, 48)
# 28
# Current position:  (29, 16) Board size:  (72, 48)
# 29
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  29 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(24, 16), (25, 16), (26, 16), (27, 16), (28, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (29, 16) Board size:  (72, 48)
# 29
# Current position:  (30, 16) Board size:  (72, 48)
# 30
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  30 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(25, 16), (26, 16), (27, 16), (28, 16), (29, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (30, 16) Board size:  (72, 48)
# 30
# Current position:  (31, 16) Board size:  (72, 48)
# 31
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  31 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(26, 16), (27, 16), (28, 16), (29, 16), (30, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (31, 16) Board size:  (72, 48)
# 31
# Current position:  (32, 16) Board size:  (72, 48)
# 32
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  32 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(27, 16), (28, 16), (29, 16), (30, 16), (31, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (32, 16) Board size:  (72, 48)
# 32
# Current position:  (33, 16) Board size:  (72, 48)
# 33
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  33 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(28, 16), (29, 16), (30, 16), (31, 16), (32, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (33, 16) Board size:  (72, 48)
# 33
# Current position:  (34, 16) Board size:  (72, 48)
# 34
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  34 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(29, 16), (30, 16), (31, 16), (32, 16), (33, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (34, 16) Board size:  (72, 48)
# 34
# Current position:  (35, 16) Board size:  (72, 48)
# 35
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  35 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(30, 16), (31, 16), (32, 16), (33, 16), (34, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (35, 16) Board size:  (72, 48)
# 35
# Current position:  (36, 16) Board size:  (72, 48)
# 36
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  36 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(31, 16), (32, 16), (33, 16), (34, 16), (35, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (36, 16) Board size:  (72, 48)
# 36
# Current position:  (37, 16) Board size:  (72, 48)
# 37
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  37 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(32, 16), (33, 16), (34, 16), (35, 16), (36, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (37, 16) Board size:  (72, 48)
# 37
# Current position:  (38, 16) Board size:  (72, 48)
# 38
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  38 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(33, 16), (34, 16), (35, 16), (36, 16), (37, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (38, 16) Board size:  (72, 48)
# 38
# Current position:  (39, 16) Board size:  (72, 48)
# 39
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  39 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(34, 16), (35, 16), (36, 16), (37, 16), (38, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (39, 16) Board size:  (72, 48)
# 39
# Current position:  (40, 16) Board size:  (72, 48)
# 40
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  40 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(35, 16), (36, 16), (37, 16), (38, 16), (39, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (40, 16) Board size:  (72, 48)
# 40
# Current position:  (41, 16) Board size:  (72, 48)
# 41
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  41 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(36, 16), (37, 16), (38, 16), (39, 16), (40, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (41, 16) Board size:  (72, 48)
# 41
# Current position:  (42, 16) Board size:  (72, 48)
# 42
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  42 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(37, 16), (38, 16), (39, 16), (40, 16), (41, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (42, 16) Board size:  (72, 48)
# 42
# Current position:  (43, 16) Board size:  (72, 48)
# 43
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  43 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(38, 16), (39, 16), (40, 16), (41, 16), (42, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (43, 16) Board size:  (72, 48)
# 43
# Current position:  (44, 16) Board size:  (72, 48)
# 44
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  44 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(39, 16), (40, 16), (41, 16), (42, 16), (43, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (44, 16) Board size:  (72, 48)
# 44
# Current position:  (45, 16) Board size:  (72, 48)
# 45
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  45 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(40, 16), (41, 16), (42, 16), (43, 16), (44, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (45, 16) Board size:  (72, 48)
# 45
# Current position:  (46, 16) Board size:  (72, 48)
# 46
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  46 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(41, 16), (42, 16), (43, 16), (44, 16), (45, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (46, 16) Board size:  (72, 48)
# 46
# Current position:  (47, 16) Board size:  (72, 48)
# 47
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  47 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(42, 16), (43, 16), (44, 16), (45, 16), (46, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (47, 16) Board size:  (72, 48)
# 47
# Current position:  (48, 16) Board size:  (72, 48)
# 48
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  48 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(43, 16), (44, 16), (45, 16), (46, 16), (47, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (48, 16) Board size:  (72, 48)
# 48
# Current position:  (49, 16) Board size:  (72, 48)
# 49
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  49 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(44, 16), (45, 16), (46, 16), (47, 16), (48, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (49, 16) Board size:  (72, 48)
# 49
# Current position:  (50, 16) Board size:  (72, 48)
# 50
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  50 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(45, 16), (46, 16), (47, 16), (48, 16), (49, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (50, 16) Board size:  (72, 48)
# 50
# Current position:  (51, 16) Board size:  (72, 48)
# 51
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  51 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(46, 16), (47, 16), (48, 16), (49, 16), (50, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (51, 16) Board size:  (72, 48)
# 51
# Current position:  (52, 16) Board size:  (72, 48)
# 52
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  52 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(47, 16), (48, 16), (49, 16), (50, 16), (51, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (52, 16) Board size:  (72, 48)
# 52
# Current position:  (53, 16) Board size:  (72, 48)
# 53
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  53 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(48, 16), (49, 16), (50, 16), (51, 16), (52, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (53, 16) Board size:  (72, 48)
# 53
# Current position:  (54, 16) Board size:  (72, 48)
# 54
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  54 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(49, 16), (50, 16), (51, 16), (52, 16), (53, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (54, 16) Board size:  (72, 48)
# 54
# Current position:  (55, 16) Board size:  (72, 48)
# 55
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  55 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(50, 16), (51, 16), (52, 16), (53, 16), (54, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (55, 16) Board size:  (72, 48)
# 55
# Current position:  (56, 16) Board size:  (72, 48)
# 56
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  56 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(51, 16), (52, 16), (53, 16), (54, 16), (55, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (56, 16) Board size:  (72, 48)
# 56
# Current position:  (57, 16) Board size:  (72, 48)
# 57
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  57 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(52, 16), (53, 16), (54, 16), (55, 16), (56, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (57, 16) Board size:  (72, 48)
# 57
# Current position:  (58, 16) Board size:  (72, 48)
# 58
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  58 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(53, 16), (54, 16), (55, 16), (56, 16), (57, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (58, 16) Board size:  (72, 48)
# 58
# Current position:  (59, 16) Board size:  (72, 48)
# 59
# Apple x posiiton:  60 Apple y posiiton:  16
# Head x posiiton:  59 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(54, 16), (55, 16), (56, 16), (57, 16), (58, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (59, 16) Board size:  (72, 48)
# 59
# Current position:  (60, 16) Board size:  (72, 48)
# 60
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  60 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(54, 16), (55, 16), (56, 16), (57, 16), (58, 16), (59, 16)]
# AI Decides that snake should go  DOWN
# Options  [(0, 1)]
# Current position:  (60, 16) Board size:  (72, 48)
# 60
# Current position:  (60, 17) Board size:  (72, 48)
# 60
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  60 Apple y posiiton:  17
# Current Direction DOWN
# Current Body Positions:  [(55, 16), (56, 16), (57, 16), (58, 16), (59, 16), (60, 16)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (60, 17) Board size:  (72, 48)
# 60
# Current position:  (59, 17) Board size:  (72, 48)
# 59
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  59 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(56, 16), (57, 16), (58, 16), (59, 16), (60, 16), (60, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (59, 17) Board size:  (72, 48)
# 59
# Current position:  (58, 17) Board size:  (72, 48)
# 58
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  58 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(57, 16), (58, 16), (59, 16), (60, 16), (60, 17), (59, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (58, 17) Board size:  (72, 48)
# 58
# Current position:  (57, 17) Board size:  (72, 48)
# 57
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  57 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(58, 16), (59, 16), (60, 16), (60, 17), (59, 17), (58, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (57, 17) Board size:  (72, 48)
# 57
# Current position:  (56, 17) Board size:  (72, 48)
# 56
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  56 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(59, 16), (60, 16), (60, 17), (59, 17), (58, 17), (57, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (56, 17) Board size:  (72, 48)
# 56
# Current position:  (55, 17) Board size:  (72, 48)
# 55
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  55 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(60, 16), (60, 17), (59, 17), (58, 17), (57, 17), (56, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (55, 17) Board size:  (72, 48)
# 55
# Current position:  (54, 17) Board size:  (72, 48)
# 54
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  54 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(60, 17), (59, 17), (58, 17), (57, 17), (56, 17), (55, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (54, 17) Board size:  (72, 48)
# 54
# Current position:  (53, 17) Board size:  (72, 48)
# 53
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  53 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(59, 17), (58, 17), (57, 17), (56, 17), (55, 17), (54, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (53, 17) Board size:  (72, 48)
# 53
# Current position:  (52, 17) Board size:  (72, 48)
# 52
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  52 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(58, 17), (57, 17), (56, 17), (55, 17), (54, 17), (53, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (52, 17) Board size:  (72, 48)
# 52
# Current position:  (51, 17) Board size:  (72, 48)
# 51
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  51 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(57, 17), (56, 17), (55, 17), (54, 17), (53, 17), (52, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (51, 17) Board size:  (72, 48)
# 51
# Current position:  (50, 17) Board size:  (72, 48)
# 50
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  50 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(56, 17), (55, 17), (54, 17), (53, 17), (52, 17), (51, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (50, 17) Board size:  (72, 48)
# 50
# Current position:  (49, 17) Board size:  (72, 48)
# 49
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  49 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(55, 17), (54, 17), (53, 17), (52, 17), (51, 17), (50, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (49, 17) Board size:  (72, 48)
# 49
# Current position:  (48, 17) Board size:  (72, 48)
# 48
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  48 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(54, 17), (53, 17), (52, 17), (51, 17), (50, 17), (49, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (48, 17) Board size:  (72, 48)
# 48
# Current position:  (47, 17) Board size:  (72, 48)
# 47
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  47 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(53, 17), (52, 17), (51, 17), (50, 17), (49, 17), (48, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (47, 17) Board size:  (72, 48)
# 47
# Current position:  (46, 17) Board size:  (72, 48)
# 46
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  46 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(52, 17), (51, 17), (50, 17), (49, 17), (48, 17), (47, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (46, 17) Board size:  (72, 48)
# 46
# Current position:  (45, 17) Board size:  (72, 48)
# 45
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  45 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(51, 17), (50, 17), (49, 17), (48, 17), (47, 17), (46, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (45, 17) Board size:  (72, 48)
# 45
# Current position:  (44, 17) Board size:  (72, 48)
# 44
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  44 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(50, 17), (49, 17), (48, 17), (47, 17), (46, 17), (45, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (44, 17) Board size:  (72, 48)
# 44
# Current position:  (43, 17) Board size:  (72, 48)
# 43
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  43 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(49, 17), (48, 17), (47, 17), (46, 17), (45, 17), (44, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (43, 17) Board size:  (72, 48)
# 43
# Current position:  (42, 17) Board size:  (72, 48)
# 42
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  42 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(48, 17), (47, 17), (46, 17), (45, 17), (44, 17), (43, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (42, 17) Board size:  (72, 48)
# 42
# Current position:  (41, 17) Board size:  (72, 48)
# 41
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  41 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(47, 17), (46, 17), (45, 17), (44, 17), (43, 17), (42, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (41, 17) Board size:  (72, 48)
# 41
# Current position:  (40, 17) Board size:  (72, 48)
# 40
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  40 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(46, 17), (45, 17), (44, 17), (43, 17), (42, 17), (41, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (40, 17) Board size:  (72, 48)
# 40
# Current position:  (39, 17) Board size:  (72, 48)
# 39
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  39 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(45, 17), (44, 17), (43, 17), (42, 17), (41, 17), (40, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (39, 17) Board size:  (72, 48)
# 39
# Current position:  (38, 17) Board size:  (72, 48)
# 38
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  38 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(44, 17), (43, 17), (42, 17), (41, 17), (40, 17), (39, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (38, 17) Board size:  (72, 48)
# 38
# Current position:  (37, 17) Board size:  (72, 48)
# 37
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  37 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(43, 17), (42, 17), (41, 17), (40, 17), (39, 17), (38, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (37, 17) Board size:  (72, 48)
# 37
# Current position:  (36, 17) Board size:  (72, 48)
# 36
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  36 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(42, 17), (41, 17), (40, 17), (39, 17), (38, 17), (37, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (36, 17) Board size:  (72, 48)
# 36
# Current position:  (35, 17) Board size:  (72, 48)
# 35
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  35 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(41, 17), (40, 17), (39, 17), (38, 17), (37, 17), (36, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (35, 17) Board size:  (72, 48)
# 35
# Current position:  (34, 17) Board size:  (72, 48)
# 34
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  34 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(40, 17), (39, 17), (38, 17), (37, 17), (36, 17), (35, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (34, 17) Board size:  (72, 48)
# 34
# Current position:  (33, 17) Board size:  (72, 48)
# 33
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  33 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(39, 17), (38, 17), (37, 17), (36, 17), (35, 17), (34, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (33, 17) Board size:  (72, 48)
# 33
# Current position:  (32, 17) Board size:  (72, 48)
# 32
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  32 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(38, 17), (37, 17), (36, 17), (35, 17), (34, 17), (33, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (32, 17) Board size:  (72, 48)
# 32
# Current position:  (31, 17) Board size:  (72, 48)
# 31
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  31 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(37, 17), (36, 17), (35, 17), (34, 17), (33, 17), (32, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (31, 17) Board size:  (72, 48)
# 31
# Current position:  (30, 17) Board size:  (72, 48)
# 30
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  30 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(36, 17), (35, 17), (34, 17), (33, 17), (32, 17), (31, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (30, 17) Board size:  (72, 48)
# 30
# Current position:  (29, 17) Board size:  (72, 48)
# 29
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  29 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(35, 17), (34, 17), (33, 17), (32, 17), (31, 17), (30, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (29, 17) Board size:  (72, 48)
# 29
# Current position:  (28, 17) Board size:  (72, 48)
# 28
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  28 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(34, 17), (33, 17), (32, 17), (31, 17), (30, 17), (29, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (28, 17) Board size:  (72, 48)
# 28
# Current position:  (27, 17) Board size:  (72, 48)
# 27
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  27 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(33, 17), (32, 17), (31, 17), (30, 17), (29, 17), (28, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (27, 17) Board size:  (72, 48)
# 27
# Current position:  (26, 17) Board size:  (72, 48)
# 26
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  26 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(32, 17), (31, 17), (30, 17), (29, 17), (28, 17), (27, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (26, 17) Board size:  (72, 48)
# 26
# Current position:  (25, 17) Board size:  (72, 48)
# 25
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  25 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(31, 17), (30, 17), (29, 17), (28, 17), (27, 17), (26, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (25, 17) Board size:  (72, 48)
# 25
# Current position:  (24, 17) Board size:  (72, 48)
# 24
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  24 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(30, 17), (29, 17), (28, 17), (27, 17), (26, 17), (25, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (24, 17) Board size:  (72, 48)
# 24
# Current position:  (23, 17) Board size:  (72, 48)
# 23
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  23 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(29, 17), (28, 17), (27, 17), (26, 17), (25, 17), (24, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (23, 17) Board size:  (72, 48)
# 23
# Current position:  (22, 17) Board size:  (72, 48)
# 22
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  22 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(28, 17), (27, 17), (26, 17), (25, 17), (24, 17), (23, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (22, 17) Board size:  (72, 48)
# 22
# Current position:  (21, 17) Board size:  (72, 48)
# 21
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  21 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(27, 17), (26, 17), (25, 17), (24, 17), (23, 17), (22, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (21, 17) Board size:  (72, 48)
# 21
# Current position:  (20, 17) Board size:  (72, 48)
# 20
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  20 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(26, 17), (25, 17), (24, 17), (23, 17), (22, 17), (21, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (20, 17) Board size:  (72, 48)
# 20
# Current position:  (19, 17) Board size:  (72, 48)
# 19
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  19 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(25, 17), (24, 17), (23, 17), (22, 17), (21, 17), (20, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (19, 17) Board size:  (72, 48)
# 19
# Current position:  (18, 17) Board size:  (72, 48)
# 18
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  18 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(24, 17), (23, 17), (22, 17), (21, 17), (20, 17), (19, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (18, 17) Board size:  (72, 48)
# 18
# Current position:  (17, 17) Board size:  (72, 48)
# 17
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  17 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(23, 17), (22, 17), (21, 17), (20, 17), (19, 17), (18, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (17, 17) Board size:  (72, 48)
# 17
# Current position:  (16, 17) Board size:  (72, 48)
# 16
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  16 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(22, 17), (21, 17), (20, 17), (19, 17), (18, 17), (17, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (16, 17) Board size:  (72, 48)
# 16
# Current position:  (15, 17) Board size:  (72, 48)
# 15
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  15 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(21, 17), (20, 17), (19, 17), (18, 17), (17, 17), (16, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (15, 17) Board size:  (72, 48)
# 15
# Current position:  (14, 17) Board size:  (72, 48)
# 14
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  14 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(20, 17), (19, 17), (18, 17), (17, 17), (16, 17), (15, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (14, 17) Board size:  (72, 48)
# 14
# Current position:  (13, 17) Board size:  (72, 48)
# 13
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  13 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(19, 17), (18, 17), (17, 17), (16, 17), (15, 17), (14, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (13, 17) Board size:  (72, 48)
# 13
# Current position:  (12, 17) Board size:  (72, 48)
# 12
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  12 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(18, 17), (17, 17), (16, 17), (15, 17), (14, 17), (13, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (12, 17) Board size:  (72, 48)
# 12
# Current position:  (11, 17) Board size:  (72, 48)
# 11
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  11 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(17, 17), (16, 17), (15, 17), (14, 17), (13, 17), (12, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (11, 17) Board size:  (72, 48)
# 11
# Current position:  (10, 17) Board size:  (72, 48)
# 10
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  10 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(16, 17), (15, 17), (14, 17), (13, 17), (12, 17), (11, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (10, 17) Board size:  (72, 48)
# 10
# Current position:  (9, 17) Board size:  (72, 48)
# 9
# Apple x posiiton:  8 Apple y posiiton:  17
# Head x posiiton:  9 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(15, 17), (14, 17), (13, 17), (12, 17), (11, 17), (10, 17)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (9, 17) Board size:  (72, 48)
# 9
# Current position:  (8, 17) Board size:  (72, 48)
# 8
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  8 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(15, 17), (14, 17), (13, 17), (12, 17), (11, 17), (10, 17), (9, 17)]
# AI Decides that snake should go  UP
# Options  [(0, -1)]
# Current position:  (8, 17) Board size:  (72, 48)
# 8
# Current position:  (8, 16) Board size:  (72, 48)
# 8
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  8 Apple y posiiton:  16
# Current Direction UP
# Current Body Positions:  [(14, 17), (13, 17), (12, 17), (11, 17), (10, 17), (9, 17), (8, 17)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (8, 16) Board size:  (72, 48)
# 8
# Current position:  (9, 16) Board size:  (72, 48)
# 9
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  9 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(13, 17), (12, 17), (11, 17), (10, 17), (9, 17), (8, 17), (8, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (9, 16) Board size:  (72, 48)
# 9
# Current position:  (10, 16) Board size:  (72, 48)
# 10
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  10 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(12, 17), (11, 17), (10, 17), (9, 17), (8, 17), (8, 16), (9, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (10, 16) Board size:  (72, 48)
# 10
# Current position:  (11, 16) Board size:  (72, 48)
# 11
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  11 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(11, 17), (10, 17), (9, 17), (8, 17), (8, 16), (9, 16), (10, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (11, 16) Board size:  (72, 48)
# 11
# Current position:  (12, 16) Board size:  (72, 48)
# 12
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  12 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(10, 17), (9, 17), (8, 17), (8, 16), (9, 16), (10, 16), (11, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (12, 16) Board size:  (72, 48)
# 12
# Current position:  (13, 16) Board size:  (72, 48)
# 13
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  13 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(9, 17), (8, 17), (8, 16), (9, 16), (10, 16), (11, 16), (12, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (13, 16) Board size:  (72, 48)
# 13
# Current position:  (14, 16) Board size:  (72, 48)
# 14
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  14 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(8, 17), (8, 16), (9, 16), (10, 16), (11, 16), (12, 16), (13, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (14, 16) Board size:  (72, 48)
# 14
# Current position:  (15, 16) Board size:  (72, 48)
# 15
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  15 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(8, 16), (9, 16), (10, 16), (11, 16), (12, 16), (13, 16), (14, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (15, 16) Board size:  (72, 48)
# 15
# Current position:  (16, 16) Board size:  (72, 48)
# 16
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  16 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(9, 16), (10, 16), (11, 16), (12, 16), (13, 16), (14, 16), (15, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (16, 16) Board size:  (72, 48)
# 16
# Current position:  (17, 16) Board size:  (72, 48)
# 17
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  17 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(10, 16), (11, 16), (12, 16), (13, 16), (14, 16), (15, 16), (16, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (17, 16) Board size:  (72, 48)
# 17
# Current position:  (18, 16) Board size:  (72, 48)
# 18
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  18 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(11, 16), (12, 16), (13, 16), (14, 16), (15, 16), (16, 16), (17, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (18, 16) Board size:  (72, 48)
# 18
# Current position:  (19, 16) Board size:  (72, 48)
# 19
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  19 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(12, 16), (13, 16), (14, 16), (15, 16), (16, 16), (17, 16), (18, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (19, 16) Board size:  (72, 48)
# 19
# Current position:  (20, 16) Board size:  (72, 48)
# 20
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  20 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(13, 16), (14, 16), (15, 16), (16, 16), (17, 16), (18, 16), (19, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (20, 16) Board size:  (72, 48)
# 20
# Current position:  (21, 16) Board size:  (72, 48)
# 21
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  21 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(14, 16), (15, 16), (16, 16), (17, 16), (18, 16), (19, 16), (20, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (21, 16) Board size:  (72, 48)
# 21
# Current position:  (22, 16) Board size:  (72, 48)
# 22
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  22 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(15, 16), (16, 16), (17, 16), (18, 16), (19, 16), (20, 16), (21, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (22, 16) Board size:  (72, 48)
# 22
# Current position:  (23, 16) Board size:  (72, 48)
# 23
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  23 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(16, 16), (17, 16), (18, 16), (19, 16), (20, 16), (21, 16), (22, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (23, 16) Board size:  (72, 48)
# 23
# Current position:  (24, 16) Board size:  (72, 48)
# 24
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  24 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(17, 16), (18, 16), (19, 16), (20, 16), (21, 16), (22, 16), (23, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (24, 16) Board size:  (72, 48)
# 24
# Current position:  (25, 16) Board size:  (72, 48)
# 25
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  25 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(18, 16), (19, 16), (20, 16), (21, 16), (22, 16), (23, 16), (24, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (25, 16) Board size:  (72, 48)
# 25
# Current position:  (26, 16) Board size:  (72, 48)
# 26
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  26 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(19, 16), (20, 16), (21, 16), (22, 16), (23, 16), (24, 16), (25, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (26, 16) Board size:  (72, 48)
# 26
# Current position:  (27, 16) Board size:  (72, 48)
# 27
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  27 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(20, 16), (21, 16), (22, 16), (23, 16), (24, 16), (25, 16), (26, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (27, 16) Board size:  (72, 48)
# 27
# Current position:  (28, 16) Board size:  (72, 48)
# 28
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  28 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(21, 16), (22, 16), (23, 16), (24, 16), (25, 16), (26, 16), (27, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (28, 16) Board size:  (72, 48)
# 28
# Current position:  (29, 16) Board size:  (72, 48)
# 29
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  29 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(22, 16), (23, 16), (24, 16), (25, 16), (26, 16), (27, 16), (28, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (29, 16) Board size:  (72, 48)
# 29
# Current position:  (30, 16) Board size:  (72, 48)
# 30
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  30 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(23, 16), (24, 16), (25, 16), (26, 16), (27, 16), (28, 16), (29, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (30, 16) Board size:  (72, 48)
# 30
# Current position:  (31, 16) Board size:  (72, 48)
# 31
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  31 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(24, 16), (25, 16), (26, 16), (27, 16), (28, 16), (29, 16), (30, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (31, 16) Board size:  (72, 48)
# 31
# Current position:  (32, 16) Board size:  (72, 48)
# 32
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  32 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(25, 16), (26, 16), (27, 16), (28, 16), (29, 16), (30, 16), (31, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (32, 16) Board size:  (72, 48)
# 32
# Current position:  (33, 16) Board size:  (72, 48)
# 33
# Apple x posiiton:  34 Apple y posiiton:  16
# Head x posiiton:  33 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(26, 16), (27, 16), (28, 16), (29, 16), (30, 16), (31, 16), (32, 16)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (33, 16) Board size:  (72, 48)
# 33
# Current position:  (34, 16) Board size:  (72, 48)
# 34
# Apple x posiiton:  28 Apple y posiiton:  22
# Head x posiiton:  34 Apple y posiiton:  16
# Current Direction RIGHT
# Current Body Positions:  [(26, 16), (27, 16), (28, 16), (29, 16), (30, 16), (31, 16), (32, 16), (33, 16)]
# AI Decides that snake should go  DOWN
# Options  [(0, 1)]
# Current position:  (34, 16) Board size:  (72, 48)
# 34
# Current position:  (34, 17) Board size:  (72, 48)
# 34
# Apple x posiiton:  28 Apple y posiiton:  22
# Head x posiiton:  34 Apple y posiiton:  17
# Current Direction DOWN
# Current Body Positions:  [(27, 16), (28, 16), (29, 16), (30, 16), (31, 16), (32, 16), (33, 16), (34, 16)]
# AI Decides that snake should go  LEFT
# Options  [(0, 1), (-1, 0)]
# Current position:  (34, 17) Board size:  (72, 48)
# 34
# Current position:  (33, 17) Board size:  (72, 48)
# 33
# Apple x posiiton:  28 Apple y posiiton:  22
# Head x posiiton:  33 Apple y posiiton:  17
# Current Direction LEFT
# Current Body Positions:  [(28, 16), (29, 16), (30, 16), (31, 16), (32, 16), (33, 16), (34, 16), (34, 17)]
# ...
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (27, 40) Board size:  (72, 48)
# 27
# Current position:  (26, 40) Board size:  (72, 48)
# 26
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  26 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(52, 36), (51, 36), (50, 36), (50, 37), (49, 37), (49, 38), (48, 38), (47, 38), (46, 38), (45, 38), (45, 39), (44, 39), (44, 40), (43, 40), (42, 40), (41, 40), (40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (26, 40) Board size:  (72, 48)
# 26
# Current position:  (25, 40) Board size:  (72, 48)
# 25
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  25 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(51, 36), (50, 36), (50, 37), (49, 37), (49, 38), (48, 38), (47, 38), (46, 38), (45, 38), (45, 39), (44, 39), (44, 40), (43, 40), (42, 40), (41, 40), (40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (25, 40) Board size:  (72, 48)
# 25
# Current position:  (24, 40) Board size:  (72, 48)
# 24
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  24 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(50, 36), (50, 37), (49, 37), (49, 38), (48, 38), (47, 38), (46, 38), (45, 38), (45, 39), (44, 39), (44, 40), (43, 40), (42, 40), (41, 40), (40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (24, 40) Board size:  (72, 48)
# 24
# Current position:  (23, 40) Board size:  (72, 48)
# 23
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  23 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(50, 37), (49, 37), (49, 38), (48, 38), (47, 38), (46, 38), (45, 38), (45, 39), (44, 39), (44, 40), (43, 40), (42, 40), (41, 40), (40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (23, 40) Board size:  (72, 48)
# 23
# Current position:  (22, 40) Board size:  (72, 48)
# 22
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  22 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(49, 37), (49, 38), (48, 38), (47, 38), (46, 38), (45, 38), (45, 39), (44, 39), (44, 40), (43, 40), (42, 40), (41, 40), (40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (22, 40) Board size:  (72, 48)
# 22
# Current position:  (21, 40) Board size:  (72, 48)
# 21
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  21 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(49, 38), (48, 38), (47, 38), (46, 38), (45, 38), (45, 39), (44, 39), (44, 40), (43, 40), (42, 40), (41, 40), (40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (21, 40) Board size:  (72, 48)
# 21
# Current position:  (20, 40) Board size:  (72, 48)
# 20
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  20 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(48, 38), (47, 38), (46, 38), (45, 38), (45, 39), (44, 39), (44, 40), (43, 40), (42, 40), (41, 40), (40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (20, 40) Board size:  (72, 48)
# 20
# Current position:  (19, 40) Board size:  (72, 48)
# 19
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  19 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(47, 38), (46, 38), (45, 38), (45, 39), (44, 39), (44, 40), (43, 40), (42, 40), (41, 40), (40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (19, 40) Board size:  (72, 48)
# 19
# Current position:  (18, 40) Board size:  (72, 48)
# 18
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  18 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(46, 38), (45, 38), (45, 39), (44, 39), (44, 40), (43, 40), (42, 40), (41, 40), (40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (18, 40) Board size:  (72, 48)
# 18
# Current position:  (17, 40) Board size:  (72, 48)
# 17
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  17 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(45, 38), (45, 39), (44, 39), (44, 40), (43, 40), (42, 40), (41, 40), (40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (17, 40) Board size:  (72, 48)
# 17
# Current position:  (16, 40) Board size:  (72, 48)
# 16
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  16 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(45, 39), (44, 39), (44, 40), (43, 40), (42, 40), (41, 40), (40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40), (17, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (16, 40) Board size:  (72, 48)
# 16
# Current position:  (15, 40) Board size:  (72, 48)
# 15
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  15 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(44, 39), (44, 40), (43, 40), (42, 40), (41, 40), (40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40), (17, 40), (16, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (15, 40) Board size:  (72, 48)
# 15
# Current position:  (14, 40) Board size:  (72, 48)
# 14
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  14 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(44, 40), (43, 40), (42, 40), (41, 40), (40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40), (17, 40), (16, 40), (15, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (14, 40) Board size:  (72, 48)
# 14
# Current position:  (13, 40) Board size:  (72, 48)
# 13
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  13 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(43, 40), (42, 40), (41, 40), (40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40), (17, 40), (16, 40), (15, 40), (14, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (13, 40) Board size:  (72, 48)
# 13
# Current position:  (12, 40) Board size:  (72, 48)
# 12
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  12 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(42, 40), (41, 40), (40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40), (17, 40), (16, 40), (15, 40), (14, 40), (13, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (12, 40) Board size:  (72, 48)
# 12
# Current position:  (11, 40) Board size:  (72, 48)
# 11
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  11 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(41, 40), (40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40), (17, 40), (16, 40), (15, 40), (14, 40), (13, 40), (12, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (11, 40) Board size:  (72, 48)
# 11
# Current position:  (10, 40) Board size:  (72, 48)
# 10
# Apple x posiiton:  9 Apple y posiiton:  40
# Head x posiiton:  10 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40), (17, 40), (16, 40), (15, 40), (14, 40), (13, 40), (12, 40), (11, 40)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0)]
# Current position:  (10, 40) Board size:  (72, 48)
# 10
# Current position:  (9, 40) Board size:  (72, 48)
# 9
# Apple x posiiton:  7 Apple y posiiton:  35
# Head x posiiton:  9 Apple y posiiton:  40
# Current Direction LEFT
# Current Body Positions:  [(40, 40), (39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40), (17, 40), (16, 40), (15, 40), (14, 40), (13, 40), (12, 40), (11, 40), (10, 40)]
# AI Decides that snake should go  UP
# Options  [(-1, 0), (0, -1)]
# Current position:  (9, 40) Board size:  (72, 48)
# 9
# Current position:  (9, 39) Board size:  (72, 48)
# 9
# Apple x posiiton:  7 Apple y posiiton:  35
# Head x posiiton:  9 Apple y posiiton:  39
# Current Direction UP
# Current Body Positions:  [(39, 40), (38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40), (17, 40), (16, 40), (15, 40), (14, 40), (13, 40), (12, 40), (11, 40), (10, 40), (9, 40)]
# AI Decides that snake should go  UP
# Options  [(-1, 0), (0, -1)]
# Current position:  (9, 39) Board size:  (72, 48)
# 9
# Current position:  (9, 38) Board size:  (72, 48)
# 9
# Apple x posiiton:  7 Apple y posiiton:  35
# Head x posiiton:  9 Apple y posiiton:  38
# Current Direction UP
# Current Body Positions:  [(38, 40), (37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40), (17, 40), (16, 40), (15, 40), (14, 40), (13, 40), (12, 40), (11, 40), (10, 40), (9, 40), (9, 39)]
# AI Decides that snake should go  UP
# Options  [(-1, 0), (0, -1)]
# Current position:  (9, 38) Board size:  (72, 48)
# 9
# Current position:  (9, 37) Board size:  (72, 48)
# 9
# Apple x posiiton:  7 Apple y posiiton:  35
# Head x posiiton:  9 Apple y posiiton:  37
# Current Direction UP
# Current Body Positions:  [(37, 40), (36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40), (17, 40), (16, 40), (15, 40), (14, 40), (13, 40), (12, 40), (11, 40), (10, 40), (9, 40), (9, 39), (9, 38)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0), (0, -1)]
# Current position:  (9, 37) Board size:  (72, 48)
# 9
# Current position:  (8, 37) Board size:  (72, 48)
# 8
# Apple x posiiton:  7 Apple y posiiton:  35
# Head x posiiton:  8 Apple y posiiton:  37
# Current Direction LEFT
# Current Body Positions:  [(36, 40), (35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40), (17, 40), (16, 40), (15, 40), (14, 40), (13, 40), (12, 40), (11, 40), (10, 40), (9, 40), (9, 39), (9, 38), (9, 37)]
# AI Decides that snake should go  UP
# Options  [(-1, 0), (0, -1)]
# Current position:  (8, 37) Board size:  (72, 48)
# 8
# Current position:  (8, 36) Board size:  (72, 48)
# 8
# Apple x posiiton:  7 Apple y posiiton:  35
# Head x posiiton:  8 Apple y posiiton:  36
# Current Direction UP
# Current Body Positions:  [(35, 40), (34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40), (17, 40), (16, 40), (15, 40), (14, 40), (13, 40), (12, 40), (11, 40), (10, 40), (9, 40), (9, 39), (9, 38), (9, 37), (8, 37)]
# AI Decides that snake should go  LEFT
# Options  [(-1, 0), (0, -1)]
# Current position:  (8, 36) Board size:  (72, 48)
# 8
# Current position:  (7, 36) Board size:  (72, 48)
# 7
# Apple x posiiton:  7 Apple y posiiton:  35
# Head x posiiton:  7 Apple y posiiton:  36
# Current Direction LEFT
# Current Body Positions:  [(34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40), (17, 40), (16, 40), (15, 40), (14, 40), (13, 40), (12, 40), (11, 40), (10, 40), (9, 40), (9, 39), (9, 38), (9, 37), (8, 37), (8, 36)]
# AI Decides that snake should go  UP
# Options  [(0, -1)]
# Current position:  (7, 36) Board size:  (72, 48)
# 7
# Current position:  (7, 35) Board size:  (72, 48)
# 7
# Apple x posiiton:  63 Apple y posiiton:  40
# Head x posiiton:  7 Apple y posiiton:  35
# Current Direction UP
# Current Body Positions:  [(34, 40), (33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40), (17, 40), (16, 40), (15, 40), (14, 40), (13, 40), (12, 40), (11, 40), (10, 40), (9, 40), (9, 39), (9, 38), (9, 37), (8, 37), (8, 36), (7, 36)]
# AI Decides that snake should go  RIGHT
# Options  [(1, 0)]
# Current position:  (7, 35) Board size:  (72, 48)
# 7
# Current position:  (8, 35) Board size:  (72, 48)
# 8
# Apple x posiiton:  63 Apple y posiiton:  40
# Head x posiiton:  8 Apple y posiiton:  35
# Current Direction RIGHT
# Current Body Positions:  [(33, 40), (32, 40), (31, 40), (30, 40), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (22, 40), (21, 40), (20, 40), (19, 40), (18, 40), (17, 40), (16, 40), (15, 40), (14, 40), (13, 40), (12, 40), (11, 40), (10, 40), (9, 40), (9, 39), (9, 38), (9, 37), (8, 37), (8, 36), (7, 36), (7, 35)]
# AI Decides that snake should go  DOWN
# Options  [(1, 0), (0, 1)]
# Current position:  (8, 35) Board size:  (72, 48)
# 8
